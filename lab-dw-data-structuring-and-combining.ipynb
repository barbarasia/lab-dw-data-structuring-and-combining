# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

url_1 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
df_1 = pd.read_csv(url_1)

url_2 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
df_2 = pd.read_csv(url_2)

url_3 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv'
df_3 = pd.read_csv(url_3)

# %%
df = pd.concat([df_1, df_2, df_3])
df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN    NaN              Bachelor
# 7066  PK87824         NaN    NaN               College
# 7067  TD14365         NaN    NaN              Bachelor
# 7068  UP19263         NaN    NaN               College
# 7069  Y167826         NaN    NaN               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df['GENDER'] = df['GENDER'].fillna(df['Gender'])
df['State'] = df['State'].fillna(df['ST'])
df = df.drop(columns=['Gender', 'ST'])
df
# Out:
#      Customer GENDER             Education Customer Lifetime Value   Income  \
# 0     RB50392    NaN                Master                     NaN      0.0
# 1     QZ44356      F              Bachelor              697953.59%      0.0
# 2     AI49188      F              Bachelor             1288743.17%  48767.0
# 3     WW63253      M              Bachelor              764586.18%      0.0
# 4     GA49547      M  High School or Below              536307.65%  36357.0
# ...       ...    ...                   ...                     ...      ...
# 7065  LA72316      M              Bachelor             23405.98798  71941.0
# 7066  PK87824      F               College             3096.511217  21604.0
# 7067  TD14365      M              Bachelor             8163.890428      0.0
# 7068  UP19263      M               College             7524.442436  21941.0
# 7069  Y167826      M               College             2611.836866      0.0
#
# ...

# %%
df.columns = [c.lower().replace(' ','_') for c in df.columns]
df
# Out:
#      customer gender             education customer_lifetime_value   income  \
# 0     RB50392    NaN                Master                     NaN      0.0
# 1     QZ44356      F              Bachelor              697953.59%      0.0
# 2     AI49188      F              Bachelor             1288743.17%  48767.0
# 3     WW63253      M              Bachelor              764586.18%      0.0
# 4     GA49547      M  High School or Below              536307.65%  36357.0
# ...       ...    ...                   ...                     ...      ...
# 7065  LA72316      M              Bachelor             23405.98798  71941.0
# 7066  PK87824      F               College             3096.511217  21604.0
# 7067  TD14365      M              Bachelor             8163.890428      0.0
# 7068  UP19263      M               College             7524.442436  21941.0
# 7069  Y167826      M               College             2611.836866      0.0
#
# ...

# %%
df = df.dropna(how='all')
df = df.dropna(axis=1,how='all')
df
# Out:
#      customer gender             education customer_lifetime_value   income  \
# 0     RB50392    NaN                Master                     NaN      0.0
# 1     QZ44356      F              Bachelor              697953.59%      0.0
# 2     AI49188      F              Bachelor             1288743.17%  48767.0
# 3     WW63253      M              Bachelor              764586.18%      0.0
# 4     GA49547      M  High School or Below              536307.65%  36357.0
# ...       ...    ...                   ...                     ...      ...
# 7065  LA72316      M              Bachelor             23405.98798  71941.0
# 7066  PK87824      F               College             3096.511217  21604.0
# 7067  TD14365      M              Bachelor             8163.890428      0.0
# 7068  UP19263      M               College             7524.442436  21941.0
# 7069  Y167826      M               College             2611.836866      0.0
#
# ...

# %%
df['gender'].value_counts()
# Out:
# gender
# F         4560
# M         4368
# Male        40
# female      30
# Femal       17
# Name: count, dtype: int64

# %%
#df["number_of_open_complaints"] = df["number_of_open_complaints"].apply(lambda x: x.split('/')[1] if )

# %%
df["gender"] = df["gender"].apply(lambda x: x.lower() if isinstance(x, str) else x)
df["gender"] = df["gender"].apply(lambda x: 'F' if x in ["f", "femal", "female"] else x)
df["gender"] = df["gender"].apply(lambda x: 'M' if x in ["male", "m"] else x)

df.gender.value_counts()
# Out:
# gender
# F    4607
# M    4408
# Name: count, dtype: int64

# %%
df["state"] = df["state"].apply(lambda x: 'California' if x == "Cali" else x)
df["state"] = df["state"].apply(lambda x: 'Arizona' if x == "AZ" else x)
df["state"] = df["state"].apply(lambda x: 'Washington' if x == "WA" else x)
df["state"].value_counts()
# Out:
# state
# California    3152
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     798
# Name: count, dtype: int64

# %%
df["education"] = df["education"].apply(lambda x: 'Bachelor' if x == "Bachelors" else x)
df["education"].value_counts()
# Out:
# education
# Bachelor                2743
# College                 2682
# High School or Below    2616
# Master                   752
# Doctor                   344
# Name: count, dtype: int64

# %%
df["customer_lifetime_value"] = df["customer_lifetime_value"].str.replace('%', '')

# %%
df["customer_lifetime_value"] = df["customer_lifetime_value"].apply(lambda x: float(x) if isinstance(x, str) else x)
df.dtypes
# Out:
# customer                      object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# state                         object
# dtype: object

# %%
df["vehicle_class"] = df["vehicle_class"].apply(lambda x: 'Luxury' if x in ["Sports Car", "Luxury SUV", "Luxury Car"] else x)
df["vehicle_class"].value_counts()
# Out:
# vehicle_class
# Four-Door Car    4641
# Two-Door Car     1896
# SUV              1774
# Luxury            826
# Name: count, dtype: int64

# %%
df["number_of_open_complaints"] = df["number_of_open_complaints"].apply(lambda x: x.split("/")[1] if isinstance(x, str) else x)

# %%
df
# Out:
#      customer gender             education  customer_lifetime_value   income  \
# 0     RB50392    NaN                Master                      NaN      0.0
# 1     QZ44356      F              Bachelor                697953.59      0.0
# 2     AI49188      F              Bachelor               1288743.17  48767.0
# 3     WW63253      M              Bachelor                764586.18      0.0
# 4     GA49547      M  High School or Below                536307.65  36357.0
# ...       ...    ...                   ...                      ...      ...
# 7065  LA72316      M              Bachelor                      NaN  71941.0
# 7066  PK87824      F               College                      NaN  21604.0
# 7067  TD14365      M              Bachelor                      NaN      0.0
# 7068  UP19263      M               College                      NaN  21941.0
# 7069  Y167826      M               College                      NaN      0.0
#
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
url_4 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv'
df_mark = pd.read_csv(url_4)
df_mark
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
df_mark = df_mark.drop('unnamed:_0', axis=1)
df_mark
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
df_mark['gender'].value_counts()
# Out:
# gender
# F    5573
# M    5337
# Name: count, dtype: int64

# %%
#the marketing dataframe looks clean

# %%
df_mark.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month'],
#       dtype='object')

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
new_df = df_mark.pivot_table(index='sales_channel', values='customer_lifetime_value', aggfunc='sum')
new_df
# Out:
#                customer_lifetime_value
# sales_channel
# Agent                     3.305789e+07
# Branch                    2.435920e+07
# Call Center               1.736429e+07
# Web                       1.269763e+07

# %%
new_df = new_df.applymap(lambda x: round(x,2) if isinstance(x, (int, float)) else x)
new_df
# Out:
# /var/folders/4m/3s41hz7j7w53zsc7fm9h_6q80000gn/T/ipykernel_89254/4269294216.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   new_df = new_df.applymap(lambda x: round(x,2) if isinstance(x, (int, float)) else x)
#                customer_lifetime_value
# sales_channel
# Agent                      33057887.85
# Branch                     24359201.21
# Call Center                17364288.37
# Web                        12697632.90

# %%
new_df = df_mark.pivot_table(index='policy_type', columns='sales_channel', values='customer_lifetime_value')
new_df
# Out:
# sales_channel         Agent       Branch  Call Center          Web
# policy_type
# Corporate Auto  7883.130054  8087.523158  7833.846895  7453.482767
# Personal Auto   7979.303178  8043.994587  8191.682874  7877.264050
# Special Auto    9492.632625  8215.545857  8080.646953  8326.076235

# %%
new_df.describe()
# Out:
# sales_channel        Agent       Branch  Call Center          Web
# count             3.000000     3.000000     3.000000     3.000000
# mean           8451.688619  8115.687867  8035.392241  7885.607684
# std             902.765548    89.176217   183.160145   436.356565
# min            7883.130054  8043.994587  7833.846895  7453.482767
# 25%            7931.216616  8065.758872  7957.246924  7665.373409
# 50%            7979.303178  8087.523158  8080.646953  7877.264050
# 75%            8735.967902  8151.534507  8136.164914  8101.670142
# max            9492.632625  8215.545857  8191.682874  8326.076235

# %%
#agents are bringing the most quantity of insurance, average revenue is the same among the channels

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
df_mark.pivot_table(index='gender', columns='education', values='customer_lifetime_value', aggfunc='mean')
# Out:
# education     Bachelor      College       Doctor  High School or Below  \
# gender
# F          7874.269478  7748.823325  7328.508916           8675.220201
# M          7703.601675  8052.459288  7415.333638           8149.687783
#
# education       Master
# gender
# F          8157.053154
# M          8168.832659

# %%
# the average customer lifetime value is quite uniform through gender and education

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
